# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("netflix_titles.csv")
display(df.head(5))
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
columns = df.columns
display(columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
filtered_movies_df = df[df["type"] == "Movie"]
display(filtered_movies_df.head(5))
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                                 NaN
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
max = filtered_movies_df["release_year"].max()
min = filtered_movies_df["release_year"].min()
mean = filtered_movies_df["release_year"].mean()
print(f"max: {max} min {min} mean {mean}")
# Out:
# max: 2021 min 1993 mean 2015.2

# %%
filtered_movies_df["duration"] = filtered_movies_df["duration"].str.replace("min", "").str.strip()
display(filtered_movies_df.head(5))

# %%
filtered_movies_df["duration"] = pd.to_numeric(filtered_movies_df["duration"], errors='coerce')
print(filtered_movies_df["duration"].dtype)

# %%
max = filtered_movies_df["duration"].max()
min = filtered_movies_df["duration"].min()  
mean = filtered_movies_df["duration"].mean()
print(f"max: {max} min {min} mean {mean}")
# Out:
# max: 312.0 min 3.0 mean 99.57718668407311

# %%
counts = filtered_movies_df["listed_in"].value_counts()
print(counts)
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
#                                                    ...
# Sci-Fi & Fantasy                                      1
# Sports Movies                                         1
# Children & Family Movies, Comedies, Cult Movies       1
# Cult Movies, Dramas, Music & Musicals                 1
# Cult Movies, Dramas, Thrillers                        1
# Name: count, Length: 278, dtype: int64

# %%
fYear = df[df["release_year"] == 2021]

# %%
with pd.option_context('display.max_rows', None): print(fYear["listed_in"].value_counts())
# Out:
# listed_in
# Kids' TV                                                                           24
# Documentaries                                                                      20
# Reality TV                                                                         18
# Docuseries                                                                         15
# Comedies, Dramas, International Movies                                             15
# Children & Family Movies, Comedies                                                 13
# Children & Family Movies                                                           12
# Stand-Up Comedy                                                                    12
# Dramas, Independent Movies, International Movies                                   11
# International TV Shows, TV Dramas                                                  11
# Action & Adventure, International Movies                                           10
# ...

# %%
#Count how many entries for each genre
print(df["listed_in"].value_counts())
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
# Total number of unique titles
print(df["title"].nunique())
# Out:
# 8807

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Most frequent maturity rating
print(df["rating"].value_counts())
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %%
#top genres
print(df["listed_in"].value_counts().head(5))
# Out:
# listed_in
# Dramas, International Movies                        362
# Documentaries                                       359
# Stand-Up Comedy                                     334
# Comedies, Dramas, International Movies              274
# Dramas, Independent Movies, International Movies    252
# Name: count, dtype: int64

# %%
#top cproducing countries
print(df["country"].value_counts().head(1))
# Out:
# country
# United States    2818
# Name: count, dtype: int64

# %%
print(df["release_year"].value_counts())
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
print(df["date_added"].value_counts())
# Out:
# date_added
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# December 4, 2016       1
# November 21, 2016      1
# November 19, 2016      1
# November 17, 2016      1
# January 11, 2020       1
# Name: count, Length: 1767, dtype: int64

# %%
# doing it by year instead
spl = df
display(spl)

# %%
spl["date_added"] = spl["date_added"].str[-4:]
display(spl.value_counts("date_added"))
# Out:
# date_added
# 2019    2016
# 2020    1879
# 2018    1649
# 2021    1498
# 2017    1188
# 2016     429
# 2015      82
# 2014      24
# 2011      13
# 2013      11
# 2012       3
# 2008       2
# 2009       2
# 2010       1
# Name: count, dtype: int64

# %%
# calculate the avergae length of a movie
spl = df[df["type"] == "Movie"].copy()
spl["duration"] = spl["duration"].str.replace("min", "")
display(spl)
spl["duration"] = pd.to_numeric(spl["duration"], errors ="coerce")
print(spl["duration"].mean())
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
# longest and shortest movies
min = spl["duration"].min()
max = spl["duration"].max()
print(min,max)
display(spl[spl["duration"]==3.0])
# Out:
# 3.0 312.0
#      show_id   type   title                           director cast  \
# 3777   s3778  Movie  Silent  Limbert Fabian, Brandon Oldenburg  NaN
#
#             country    date_added  release_year rating  duration  \
# 3777  United States  June 4, 2019          2014   TV-Y       3.0
#
#                                        listed_in  \
# 3777  Children & Family Movies, Sci-Fi & Fantasy
#
#                                             description
# 3777  "Silent" is an animated short film created by ...

# %%
#Find which genre is most popular in each country
#Ideas create many different slices with different countries and find the most popular genre in each
# What if multiple countries / genres listed

ex1 = df.dropna(subset=["country","listed_in"]).copy()


ex1["country"] = ex1["country"].str.split(", ")
ex1 = ex1.explode("country")
ex1["listed_in"] = ex1["listed_in"].str.split(", ")
ex1.explode("listed_in")
#display(ex1)
genre_counts = df.groupby(['country', 'listed_in']).size().reset_index(name='count')
most_common_genre = genre_counts.sort_values('count', ascending=False).drop_duplicates('country')
display(most_common_genre)
# Out:
#                          country  \
# 2153               United States
# 810                        India
# 1050                       Japan
# 1465                 South Korea
# 1772              United Kingdom
# ...                          ...
# 1015  Italy, France, Switzerland
# 1010       Italy, Canada, France
# 1009       Italy, Brazil, Greece
# 1008              Italy, Belgium
# 2643                    Zimbabwe
#
#                                               listed_in  count
# 2153                                      Documentaries    249
# 810              Comedies, Dramas, International Movies    120
# 1050               Anime Series, International TV Shows     75
# 1465  International TV Shows, Korean TV Shows, Roman...     63
# 1772                                      Documentaries     40
# ...                                                 ...    ...
# 1015            Dramas, International Movies, Thrillers      1
# ...

# %%
#See which genres are associated with which ratings
#print(df.columns)
ex2 = df.dropna(subset = ["listed_in","rating"]).copy()
ex2["listed_in"] = ex2["listed_in"].str.split(", ")
ex2 = ex2.explode("listed_in")
group = ex2.groupby(["listed_in","rating"]).size().reset_index(name="Count")
mostCommonRatings = group.sort_values(["listed_in","Count"], ascending = [True,False])
Top3 = mostCommonRatings.groupby("listed_in").head(3)
display(Top3)
# Out:
#               listed_in rating  Count
# 4    Action & Adventure      R    220
# 5    Action & Adventure  TV-14    213
# 6    Action & Adventure  TV-MA    201
# 12       Anime Features  TV-14     23
# 15       Anime Features  TV-PG     19
# ..                  ...    ...    ...
# 300       Teen TV Shows  TV-MA     20
# 301       Teen TV Shows  TV-PG     15
# 307           Thrillers  TV-MA    240
# 305           Thrillers      R    153
# 306           Thrillers  TV-14    119
#
# [126 rows x 3 columns]

# %%
# Visualise when new content added throughout the years
# organising the data to be in th eright forat for matplotlib

ex3 = df.dropna(subset=["date_added"]).copy()
ex3["date_added"] = pd.to_datetime(ex3["date_added"], errors="coerce")

ex3["MY"] = ex3["date_added"].dt.strftime("%B %Y")
display(ex3.sample(5))
groups = ex3["MY"].value_counts().reset_index()
groups["MY_dt"] = (pd.to_datetime(groups["MY"], errors = "coerce"))
groups= groups.sort_values("MY_dt")
display(groups)
#
# Out:
#      show_id     type                        title           director  \
# 118     s119    Movie                      Gurgaon      Shanker Raman
# 1501   s1502    Movie            After We Collided       Roger Kumble
# 183     s184    Movie          In the Line of Fire  Wolfgang Petersen
# 8235   s8236  TV Show                  The Calling              Bumpy
# 124     s125  TV Show  Pororo - The Little Penguin                NaN
#
#                                                    cast        country  \
# 118   Akshay Oberoi, Pankaj Tripathi, Ragini Khanna,...          India
# 1501  Josephine Langford, Hero Fiennes Tiffin, Dylan...  United States
# 183   Clint Eastwood, John Malkovich, Rene Russo, Dy...  United States
# 8235                                                NaN          India
# 124                                                 NaN    South Korea
#
#      date_added  release_year rating   duration  \
# 118  2021-09-02          2017  TV-14    106 min
# ...

# %%
# assigning the x and y axis 
xvalues = groups["MY"]
yvalues = groups["count"]
plt.bar(xvalues,yvalues)
plt.xticks(groups["MY"][::6],rotation=45)
plt.show()

# %%
#Compare the average duration of older vs newer content
# Define old vs new 
#Split into two different groups and find average

ex4 = df
ex4 = ex4[ex4["type"]=="Movie"].copy()
#display(ex4.head(3))
ex4["duration"] = ex4["duration"].str.replace(" min","")
#display(ex4.head(3))
ex4["duration"] = pd.to_numeric(ex4["duration"], errors="coerce")
#display(ex4.head(3))
oldMovies = ex4[ex4["release_year"]<2020]
newMovies = ex4[ex4["release_year"]>=2020]
oMAverage = oldMovies["duration"].mean()
nMAverage = newMovies["duration"].mean()

display(f"Old movies: {oMAverage}, new movies: {nMAverage}")
display(ex4.sample(10))
# Out:
# 'Old movies: 100.46062992125984, new movies: 93.64231738035265'
#      show_id   type                                     title  \
# 3623   s3624  Movie                           Enter the Anime
# 7456   s7457  Movie                                      Milk
# 8013   s8014  Movie                                   Shutter
# 56       s57  Movie  Naruto Shippuden the Movie: Blood Prison
# 573     s574  Movie                             Kung Fu Panda
# 3058   s3059  Movie                       Garfield's Fun Fest
# 5638   s5639  Movie                             Very Big Shot
# 7997   s7998  Movie                             Shark Busters
# 3472   s3473  Movie               Rugrats in Paris: The Movie
# 7234   s7235  Movie                                    Krisha
#
#                                       director  \
# 3623                             Alex Burunova
# 7456                              Gus Van Sant
# 8013  Banjong Pisanthanakun, Parkpoom Wongpoom
# ...

# %%
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...
